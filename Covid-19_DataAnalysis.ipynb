# %%
# ============================================================
# COVID-19 Analysis and Visualization using Plotly Express
# ============================================================

# --- Import Libraries ---
import pandas as pd
import numpy as np
import plotly.express as px

# --- Load Dataset ---
df = pd.read_csv("covid.csv")

# --- Basic Information ---
print("Dataset Shape:", df.shape)
print("Columns:", df.columns.to_list())

# --- Preprocessing ---
rename_map = {
    'Country/Region': 'Country',
    'TotalCases': 'Total_Cases',
    'TotalDeaths': 'Total_Deaths',
    'TotalRecovered': 'Total_Recovered',
    'ActiveCases': 'Active_Cases',
    'TotalTests': 'Total_Tests',
    'Population': 'Population',
    'Continent': 'Continent'
}
df.rename(columns=rename_map, inplace=True)

# Convert numeric columns
numeric_cols = [
    'Total_Cases', 'Total_Deaths', 'Total_Recovered', 'Active_Cases',
    'Total_Tests', 'Population'
]
for col in numeric_cols:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')

# Compute missing Active Cases
if 'Active_Cases' not in df.columns or df['Active_Cases'].isna().all():
    df['Active_Cases'] = df['Total_Cases'].fillna(0) - df['Total_Recovered'].fillna(0) - df['Total_Deaths'].fillna(0)

# Drop rows missing country
df = df.dropna(subset=['Country'])
print("\nData cleaned successfully!")

# --- Summary Statistics ---
# If Date does not exist, create a dummy date column for plotting
if 'Date' not in df.columns:
    df['Date'] = pd.to_datetime('2025-10-06')  # You can use today's date

latest_date = df['Date'].max()
print("Latest Date in Dataset:", latest_date.date())

df_latest = df.groupby('Country', as_index=False).last()

# --- Plot 1: Top 15 Countries by Total Cases ---
fig1 = px.bar(
    df_latest.sort_values('Total_Cases', ascending=False).head(15),
    x='Country', y='Total_Cases', color='Total_Cases',
    title='Top 15 Countries by Total COVID-19 Cases'
)
fig1.show()

# --- Plot 2: Global Daily New Cases Over Time ---
if 'New_Cases' in df.columns:
    df_global = df.groupby('Date', as_index=False)['New_Cases'].sum()
    fig2 = px.line(
        df_global, x='Date', y='New_Cases',
        title='Global Daily New COVID-19 Cases Over Time'
    )
    fig2.show()

# --- Plot 3: Total Deaths vs Total Cases ---
fig3 = px.scatter(
    df_latest, x='Total_Cases', y='Total_Deaths',
    color='Continent' if 'Continent' in df_latest.columns else None,
    size='Total_Deaths', hover_name='Country', log_x=True, log_y=True,
    title='Total Deaths vs Total Cases (Log Scale)'
)
fig3.show()

# --- Plot 4: Total Cases vs Population ---
if 'Population' in df_latest.columns:
    fig4 = px.scatter(
        df_latest, x='Population', y='Total_Cases',
        hover_name='Country', color='Continent' if 'Continent' in df_latest.columns else None,
        log_x=True, log_y=True, size='Total_Cases',
        title='Total COVID-19 Cases vs Population (Log Scale)'
    )
    fig4.show()

# --- Plot 5: Total Cases by Continent ---
if 'Continent' in df_latest.columns:
    df_cont = df_latest.groupby('Continent', as_index=False)['Total_Cases'].sum()
    fig5 = px.bar(
        df_cont, x='Continent', y='Total_Cases', color='Continent',
        title='Total COVID-19 Cases by Continent'
    )
    fig5.show()

# --- Plot 6: Animated Choropleth Map (Spread Over Time) ---
if {'Date', 'Country', 'Total_Cases'}.issubset(df.columns):
    fig6 = px.choropleth(
        df, locations='Country', locationmode='country names',
        color='Total_Cases', hover_name='Country',
        animation_frame=df['Date'].dt.strftime('%Y-%m-%d'),
        title='COVID-19 Spread Over Time (Animated Map)',
        color_continuous_scale='Reds'
    )
    fig6.show()

# --- Insights ---
print("\nKey Insights:")
print("- Global pandemic peaks identified using new case trends.")
print("- Mortality and recovery rates vary by country and population size.")
print("- Interactive visualizations help policymakers understand severity.")
print("- Plotly Express allows easy exploration of dynamic COVID-19 data.")

print("\n✅ Analysis Complete!")
# Out:
# Dataset Shape: (15, 14)
# Columns: ['Country/Region', 'Continent', 'Population', 'TotalCases', 'TotalDeaths', 'TotalRecovered', 'ActiveCases', 'Serious,Critical', 'Tot Cases/1M pop', 'Deaths/1M pop', 'TotalTests', 'Tests/1M pop', 'WHO Region', 'iso_alpha']
#
# Data cleaned successfully!
# Latest Date in Dataset: 2025-10-06
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="172069ea-f4b5-4c84-aea2-ab55429b2865" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("172069ea-f4b5-4c84-aea2-ab55429b2865")) {                    Plotly.newPlot(                        "172069ea-f4b5-4c84-aea2-ab55429b2865",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}\u003cbr\u003eTotal_Cases=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[50213719,32057192,20560489,18789416,5981844,4626910,3666717,3666717,3577700,3531500,3319050,3217456,2818633,2818633,2496531],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["USA","Brazil","India","Russia","South Africa","Mexico","Chile","Peru","Colombia","Spain","Iran","UK","Saudi Arabia","Pakistan","Bangladesh"],"xaxis":"x","y":[50213719,32057192,20560489,18789416,5981844,4626910,3666717,3666717,3577700,3531500,3319050,3217456,2818633,2818633,2496531],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}} ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ca40cb7d-c10e-4f4f-a133-203b4592816f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca40cb7d-c10e-4f4f-a133-203b4592816f")) {                    Plotly.newPlot(                        "ca40cb7d-c10e-4f4f-a133-203b4592816f",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eContinent=Asia\u003cbr\u003eTotal_Cases=%{x}\u003cbr\u003eTotal_Deaths=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Bangladesh","India","Iran","Pakistan","Saudi Arabia"],"legendgroup":"Asia","marker":{"color":"#636efa","size":[31584,478406,144000,30798,29798],"sizemode":"area","sizeref":3212.0,"symbol":"circle"},"mode":"markers","name":"Asia","orientation":"v","showlegend":true,"x":[2496531,20560489,3319050,2818633,2818633],"xaxis":"x","y":[31584,478406,144000,30798,29798],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eContinent=South America\u003cbr\u003eTotal_Cases=%{x}\u003cbr\u003eTotal_Deaths=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Brazil","Chile","Colombia","Peru"],"legendgroup":"South America","marker":{"color":"#EF553B","size":[1074698,195198,119700,218406],"sizemode":"area","sizeref":3212.0,"symbol":"circle"},"mode":"markers","name":"South America","orientation":"v","showlegend":true,"x":[32057192,3666717,3577700,3666717],"xaxis":"x","y":[1074698,195198,119700,218406],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eContinent=North America\u003cbr\u003eTotal_Cases=%{x}\u003cbr\u003eTotal_Deaths=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Mexico","USA"],"legendgroup":"North America","marker":{"color":"#00cc96","size":[306748,1284800],"sizemode":"area","sizeref":3212.0,"symbol":"circle"},"mode":"markers","name":"North America","orientation":"v","showlegend":true,"x":[4626910,50213719],"xaxis":"x","y":[306748,1284800],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eContinent=Europe\u003cbr\u003eTotal_Cases=%{x}\u003cbr\u003eTotal_Deaths=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Russia","Spain","UK"],"legendgroup":"Europe","marker":{"color":"#ab63fa","size":[394016,113300,144298],"sizemode":"area","sizeref":3212.0,"symbol":"circle"},"mode":"markers","name":"Europe","orientation":"v","showlegend":true,"x":[18789416,3531500,3217456],"xaxis":"x","y":[394016,113300,144298],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eContinent=Africa\u003cbr\u003eTotal_Cases=%{x}\u003cbr\u003eTotal_Deaths=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["South Africa"],"legendgroup":"Africa","marker":{"color":"#FFA15A","size":[96436],"sizemode":"area","sizeref":3212.0,"symbol":"circle"},"mode":"markers","name":"Africa","orientation":"v","showlegend":true,"x":[5981844],"xaxis":"x","y":[96436],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0, ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1a029fa5-4505-42f0-a5b6-e533fd2e407b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a029fa5-4505-42f0-a5b6-e533fd2e407b")) {                    Plotly.newPlot(                        "1a029fa5-4505-42f0-a5b6-e533fd2e407b",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eContinent=Asia\u003cbr\u003ePopulation=%{x}\u003cbr\u003eTotal_Cases=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Bangladesh","India","Iran","Pakistan","Saudi Arabia"],"legendgroup":"Asia","marker":{"color":"#636efa","size":[2496531,20560489,3319050,2818633,2818633],"sizemode":"area","sizeref":125534.2975,"symbol":"circle"},"mode":"markers","name":"Asia","orientation":"v","showlegend":true,"x":[164851441,1381369479,86022800,221295481,35844900],"xaxis":"x","y":[2496531,20560489,3319050,2818633,2818633],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eContinent=South America\u003cbr\u003ePopulation=%{x}\u003cbr\u003eTotal_Cases=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Brazil","Chile","Colombia","Peru"],"legendgroup":"South America","marker":{"color":"#EF553B","size":[32057192,3666717,3577700,3666717],"sizemode":"area","sizeref":125534.2975,"symbol":"circle"},"mode":"markers","name":"South America","orientation":"v","showlegend":true,"x":[217262000,19603700,52085100,33715400],"xaxis":"x","y":[32057192,3666717,3577700,3666717],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eContinent=North America\u003cbr\u003ePopulation=%{x}\u003cbr\u003eTotal_Cases=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Mexico","USA"],"legendgroup":"North America","marker":{"color":"#00cc96","size":[4626910,50213719],"sizemode":"area","sizeref":125534.2975,"symbol":"circle"},"mode":"markers","name":"North America","orientation":"v","showlegend":true,"x":[126190000,331918000],"xaxis":"x","y":[4626910,50213719],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eContinent=Europe\u003cbr\u003ePopulation=%{x}\u003cbr\u003eTotal_Cases=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Russia","Spain","UK"],"legendgroup":"Europe","marker":{"color":"#ab63fa","size":[18789416,3531500,3217456],"sizemode":"area","sizeref":125534.2975,"symbol":"circle"},"mode":"markers","name":"Europe","orientation":"v","showlegend":true,"x":[144104000,47450700,68207100],"xaxis":"x","y":[18789416,3531500,3217456],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eContinent=Africa\u003cbr\u003ePopulation=%{x}\u003cbr\u003eTotal_Cases=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["South Africa"],"legendgroup":"Africa","marker":{"color":"#FFA15A","size":[5981844],"sizemode":"area","sizeref":125534.2975,"symbol":"circle"},"mode":"markers","name":"Africa","orientation":"v","showlegend":true,"x":[59381400],"xaxis":"x","y":[5981844],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"tic ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9cc88813-0bec-4e5b-9723-3cf48b690fa4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9cc88813-0bec-4e5b-9723-3cf48b690fa4")) {                    Plotly.newPlot(                        "9cc88813-0bec-4e5b-9723-3cf48b690fa4",                        [{"alignmentgroup":"True","hovertemplate":"Continent=%{x}\u003cbr\u003eTotal_Cases=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Africa","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Africa","offsetgroup":"Africa","orientation":"v","showlegend":true,"textposition":"auto","x":["Africa"],"xaxis":"x","y":[5981844],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Continent=%{x}\u003cbr\u003eTotal_Cases=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Asia","offsetgroup":"Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["Asia"],"xaxis":"x","y":[32013336],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Continent=%{x}\u003cbr\u003eTotal_Cases=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Europe","offsetgroup":"Europe","orientation":"v","showlegend":true,"textposition":"auto","x":["Europe"],"xaxis":"x","y":[25538372],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Continent=%{x}\u003cbr\u003eTotal_Cases=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North America","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"textposition":"auto","x":["North America"],"xaxis":"x","y":[54840629],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Continent=%{x}\u003cbr\u003eTotal_Cases=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South America","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"South America","offsetgroup":"South America","orientation":"v","showlegend":true,"textposition":"auto","x":["South America"],"xaxis":"x","y":[42968326],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f1579cda-20c5-41c0-82c1-411098578aec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f1579cda-20c5-41c0-82c1-411098578aec")) {                    Plotly.newPlot(                        "f1579cda-20c5-41c0-82c1-411098578aec",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eanimation_frame=2025-10-06\u003cbr\u003eCountry=%{location}\u003cbr\u003eTotal_Cases=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["USA","Brazil","India","Russia","South Africa","Mexico","Peru","Chile","Colombia","Spain","Iran","UK","Saudi Arabia","Pakistan","Bangladesh"],"locationmode":"country names","locations":["USA","Brazil","India","Russia","South Africa","Mexico","Peru","Chile","Colombia","Spain","Iran","UK","Saudi Arabia","Pakistan","Bangladesh"],"name":"","z":[50213719,32057192,20560489,18789416,5981844,4626910,3666717,3666717,3577700,3531500,3319050,3217456,2818633,2818633,2496531],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0, ...
# Key Insights:
# - Global pandemic peaks identified using new case trends.
# - Mortality and recovery rates vary by country and population size.
# - Interactive visualizations help policymakers understand severity.
# - Plotly Express allows easy exploration of dynamic COVID-19 data.
#
# ✅ Analysis Complete!
